# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# Commented out IPython magic to ensure Python compatibility.import sklearn
import random

from sklearn.utils import shuffle
# %matplotlib inline

# %%
data=pd.read_csv('creditcard.csv')

# %%
data.head(n=7)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
# 5  0.105915  0.253844  0.081080    3.67      0
# 6 -0.257237  0.034507  0.005168    4.99      0
#
# [7 rows x 31 columns]

# %%
sns.distplot(data['Amount'])
# Out:
# H:\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Amount', ylabel='Density'>

# %%
sns.distplot(data['Time'])
# Out:
# H:\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Time', ylabel='Density'>

# %%
data.hist(figsize=(20,20))
plt.show()

# %%
d=data
sns.jointplot(x= 'Time', y= 'Amount', data= d)

class0 = d[d['Class']==0]

# %%
len(class0)
# Out:
# 284315

# %%
class1 = d[d['Class']==1]

# %%
len(class1)
# Out:
# 492

# %%
class0
temp = shuffle(class0)

# %%
d1 = temp.iloc[:2000,:]

d1
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 233650  147643.0 -3.022833 -2.149720  0.539595  0.065647  1.737525  1.594048
# 110231   71733.0 -0.359021  0.911878  1.010649 -0.455080  0.561774  0.178060
# 12926    22710.0 -0.971182  0.346778  2.724782 -1.198926  0.310189  1.545333
# 193929  130360.0  1.994410 -0.345892 -1.513107  0.327290  0.129053 -0.614168
# 90634    63096.0 -1.006295 -0.185656  1.804948 -2.469532 -1.577276 -0.414017
# ...          ...       ...       ...       ...       ...       ...       ...
# 240882  150792.0  2.104329 -2.437738 -0.608390 -2.102184 -0.169661  4.937150
# 11616    19912.0  1.375755 -0.597776  0.596852 -0.223441 -1.199637 -0.809787
# 67594    52613.0  1.117096  0.508093  0.278079  2.472947  0.143222 -0.260702
# 184100  126091.0 -0.830533  0.086026  0.647665 -2.049822 -0.255492 -0.228645
# 170759  120339.0 -0.420033 -1.525976  2.528448 -2.123893 -1.377878  0.827880
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 233650 -0.457950  0.797367  0.212528  ...  0.165876  1.339080  1.364815
# 110231  0.530635  0.207455 -0.451944  ... -0.272653 -0.788422 -0.189945
# 12926  -0.121105  0.531794  2.022263  ... -0.159845  0.201738 -0.136602
# 193929  0.129300 -0.163378  0.791620  ... -0.260472 -0.795313  0.252996
# 90634  -1.015088  0.705116 -1.966782  ... -0.013172  0.167677 -0.181300
# ...          ...       ...       ...  ...       ...       ...       ...
# 240882 -3.109476  1.403611  0.429376  ... -0.062811  0.620140  0.225374
# 11616  -0.751192 -0.150444  1.109439  ... -0.186229 -0.305837 -0.008387
# 67594   0.308862 -0.047780 -0.823145  ... -0.012046 -0.118524 -0.037904
# 184100  0.006553  0.513583 -1.720710  ... -0.042105 -0.659166  0.277436
# 170759 -1.808027  0.522894 -0.277741  ...  0.028605  0.796327 -0.072187
#
#              V24       V25       V26       V27       V28  Amount  Class
# 233650 -0.886293  0.121037  0.859267 -0.301776  0.067589   95.00      0
# 110231 -1.044773 -0.071264  0.138970  0.254857  0.095611    3.57      0
# 12926  -1.006585 -0.229750  0.979185  0.091996 -0.128803    4.60      0
# 193929  0.452079 -0.198734  0.258263 -0.097135 -0.053394   53.89      0
# 90634  -0.001432  0.287570 -0.130463  0.188480  0.047935   10.40      0
# ...          ...       ...       ...       ...       ...     ...    ...
# 240882  0.739815 -0.321490  0.042129  0.136392 -0.031000   31.60      0
# 11616   0.316008  0.470636 -0.278448 -0.026409  0.004866   20.00      0
# 67594   0.044972  0.502760  0.035988 -0.020545  0.015455   30.33      0
# 184100  0.636291 -0.457338 -0.739161 -0.039622  0.044059   70.00      0
# 170759  0.692180 -0.405731 -0.047499  0.243789  0.189866   15.45      0
#
# [2000 rows x 31 columns]

# %%
frames = [d1, class1]
df_temp = pd.concat(frames)

# %%
df_temp.info()

df= shuffle(df_temp)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2492 entries, 233650 to 281674
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    2492 non-null   float64
#  1   V1      2492 non-null   float64
#  2   V2      2492 non-null   float64
#  3   V3      2492 non-null   float64
#  4   V4      2492 non-null   float64
#  5   V5      2492 non-null   float64
#  6   V6      2492 non-null   float64
#  7   V7      2492 non-null   float64
#  8   V8      2492 non-null   float64
#  9   V9      2492 non-null   float64
#  10  V10     2492 non-null   float64
#  11  V11     2492 non-null   float64
#  12  V12     2492 non-null   float64
#  13  V13     2492 non-null   float64
#  14  V14     2492 non-null   float64
#  15  V15     2492 non-null   float64
#  16  V16     2492 non-null   float64
#  17  V17     2492 non-null   float64
#  18  V18     2492 non-null   float64
#  19  V19     2492 non-null   float64
#  20  V20     2492 non-null   float64
#  21  V21     2492 non-null   float64
#  22  V22     2492 non-null   float64
#  23  V23     2492 non-null   float64
#  24  V24     2492 non-null   float64
#  25  V25     2492 non-null   float64
#  26  V26     2492 non-null   float64
#  27  V27     2492 non-null   float64
#  28  V28     2492 non-null   float64
#  29  Amount  2492 non-null   float64
#  30  Class   2492 non-null   int64
# dtypes: float64(30), int64(1)
# memory usage: 623.0 KB

# %%
df.to_csv('creditcardsampling.csv')
sns.countplot('Class', data=df)
# Out:
# H:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
 ! pip install imblearn --user
import imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\neha\appdata\roaming\python\python37\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\neha\appdata\roaming\python\python37\site-packages (from imblearn) (0.8.1)
# Requirement already satisfied: joblib>=0.11 in h:\anaconda3\envs\detection\lib\site-packages (from imbalanced-learn->imblearn) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.24 in h:\anaconda3\envs\detection\lib\site-packages (from imbalanced-learn->imblearn) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in h:\anaconda3\envs\detection\lib\site-packages (from imbalanced-learn->imblearn) (1.21.4)
# Requirement already satisfied: scipy>=0.19.1 in h:\anaconda3\envs\detection\lib\site-packages (from imbalanced-learn->imblearn) (1.7.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in h:\anaconda3\envs\detection\lib\site-packages (from scikit-learn>=0.24->imbalanced-learn->imblearn) (3.0.0)

# %%
from imblearn.over_sampling import  SMOTE
oversample=SMOTE()
X=df.iloc[ : ,:-1]
Y=df.iloc[: , -1]
X,Y=oversample.fit_resample(X,Y)

# %%
X=pd.DataFrame(X)
X.shape
# Out:
# (4000, 30)

# %%
Y=pd.DataFrame(Y)
Y.head()
# Out:
#    Class
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0

# %%
names=['Time','V1','V2','V3','V4','V5','V6','V7','V8','V9','V10','V11','V12','V13','V14','V15','V16','V17','V18','V19','V20','V21','V22','V23','V24','V25','V26','V27','V28','Amount','Class']

# %%
data=pd.concat([X,Y],axis=1)

# %%
d=data.values

# %%
data=pd.DataFrame(d,columns=names)

# %%
data.describe()
# Out:
#                 Time           V1           V2           V3           V4  \
# count    4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean    87522.981361    -2.492796     1.853551    -3.574141     2.315960
# std     47864.232403     5.391983     3.639554     6.133857     3.158095
# min        76.000000   -30.552380   -19.730311   -31.103685    -4.459901
# 25%     46166.250000    -3.160490    -0.153419    -5.099372    -0.015245
# 50%     80975.000000    -0.828121     0.976931    -1.476594     1.446091
# 75%    133934.750000     0.824727     2.836701     0.295305     4.273766
# max    172574.000000     2.371668    22.057729     3.862590    12.114672
#
#                 V5           V6           V7           V8           V9  ...  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000  ...
# mean     -1.633140    -0.696872    -2.864221     0.261180    -1.283329  ...
# std       4.108042     1.705066     5.712306     4.844675     2.284737  ...
# min     -22.105532   -11.481330   -43.557242   -41.044261   -13.434066  ...
# 25%      -1.832360    -1.481941    -3.127276    -0.214671    -2.304756  ...
# 50%      -0.479495    -0.666661    -0.746773     0.162777    -0.772745  ...
# 75%       0.428506     0.063588     0.225654     0.843260     0.127105  ...
# max      14.927126     6.474115     9.720657    20.007208     8.272889  ...
#
#                V21          V22          V23          V24          V25  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean      0.382077    -0.001883    -0.004377    -0.057556     0.027013
# std       2.807383     1.162909     0.998437     0.540871     0.615647
# min     -22.797604    -8.887017   -19.254328    -2.501479    -4.781606
# 25%      -0.173267    -0.516347    -0.230141    -0.380822    -0.305832
# 50%       0.148169     0.020742    -0.030337    -0.007425     0.049097
# 75%       0.649679     0.540165     0.198950     0.338186     0.386337
# max      27.202839     8.361985     5.679972     1.228486     2.208209
#
#                V26          V27          V28       Amount        Class
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean      0.017443     0.077896     0.032472   103.921248     0.500000
# std       0.448809     0.966340     0.406682   235.894192     0.500063
# min      -1.403084    -7.263482    -3.713108     0.000000     0.000000
# 25%      -0.277508    -0.069794    -0.060542     2.580000     0.000000
# 50%      -0.022154     0.060001     0.034762    24.000000     0.500000
# 75%       0.304600     0.436837     0.207105    99.990000     1.000000
# max       2.745261     3.416845     2.165846  4642.200000     1.000000
#
# [8 rows x 31 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    4000 non-null   float64
#  1   V1      4000 non-null   float64
#  2   V2      4000 non-null   float64
#  3   V3      4000 non-null   float64
#  4   V4      4000 non-null   float64
#  5   V5      4000 non-null   float64
#  6   V6      4000 non-null   float64
#  7   V7      4000 non-null   float64
#  8   V8      4000 non-null   float64
#  9   V9      4000 non-null   float64
#  10  V10     4000 non-null   float64
#  11  V11     4000 non-null   float64
#  12  V12     4000 non-null   float64
#  13  V13     4000 non-null   float64
#  14  V14     4000 non-null   float64
#  15  V15     4000 non-null   float64
#  16  V16     4000 non-null   float64
#  17  V17     4000 non-null   float64
#  18  V18     4000 non-null   float64
#  19  V19     4000 non-null   float64
#  20  V20     4000 non-null   float64
#  21  V21     4000 non-null   float64
#  22  V22     4000 non-null   float64
#  23  V23     4000 non-null   float64
#  24  V24     4000 non-null   float64
#  25  V25     4000 non-null   float64
#  26  V26     4000 non-null   float64
#  27  V27     4000 non-null   float64
#  28  V28     4000 non-null   float64
#  29  Amount  4000 non-null   float64
#  30  Class   4000 non-null   float64
# dtypes: float64(31)
# memory usage: 968.9 KB

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
import math
import sklearn.preprocessing

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score , classification_report, confusion_matrix, precision_recall_curve, f1_score, auc

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop('Class', axis=1), data['Class'], test_size=0.3, random_state=42)

# %%
"""# Feature Scaling"""

cols= ['V22', 'V24', 'V25', 'V26', 'V27', 'V28']

# %%
scaler = StandardScaler()

# %%
frames= ['Time', 'Amount']

# %%
x= data[frames]

# %%
d_temp = data.drop(frames, axis=1)

# %%
temp_col=scaler.fit_transform(x)

# %%
scaled_col = pd.DataFrame(temp_col, columns=frames)

# %%
scaled_col.head()
# Out:
#        Time    Amount
# 0  0.596428 -0.165015
# 1 -0.780074 -0.360042
# 2  1.049370 -0.436357
# 3 -0.571625 -0.298142
# 4  1.137317 -0.435128

# %%
d_scaled = pd.concat([scaled_col, d_temp], axis =1)

# %%
d_scaled.head(n=9)
# Out:
#        Time    Amount        V1        V2        V3        V4        V5  \
# 0  0.596428 -0.165015  0.949241  1.333519 -4.855402  1.835006 -1.053245
# 1 -0.780074 -0.360042  1.087114 -0.411833  1.151477  1.316336 -0.318704
# 2  1.049370 -0.436357  0.674654  0.676751 -0.712336  0.027890 -0.170944
# 3 -0.571625 -0.298142 -1.642073  1.301656  1.680965  1.602124 -0.896999
# 4  1.137317 -0.435128  2.014347 -0.043837 -0.989070  0.314874 -0.065749
# 5  1.573689 -0.249767  1.934031 -0.982692 -0.702077 -1.544121 -0.806132
# 6  0.872932 -0.423977  2.125515  0.384835 -2.555122  0.441350  1.003939
# 7 -1.652212 -0.436357  0.314597  2.660670 -5.920037  4.522500 -2.315027
# 8  1.239849  0.287956  1.595819 -0.718612 -2.292155  0.068588  1.019654
#
#          V6        V7        V8  ...       V20       V21       V22       V23  \
# 0 -2.562826 -2.286986  0.260906  ...  0.424608  0.306598 -0.854627  0.101177
# 1  2.026130 -1.064364  0.610577  ... -0.072400 -0.126848  0.159447 -0.240370
# 2 -0.738997 -0.706108 -2.896737  ...  0.386881 -1.002316  1.198820 -0.048622
# 3  0.838941 -0.359057  0.955273  ...  0.130893 -0.356980 -0.432642 -0.018939
# 4 -0.925282  0.132583 -0.235218  ... -0.170608 -0.223351 -0.509404  0.330980
# 5 -0.261569 -0.800494  0.102993  ... -0.084773  0.323888  1.123082  0.063054
# 6 -1.281697  0.782023 -0.514027  ... -0.118402  0.031303  0.312674 -0.040365
# 7 -2.278352 -4.684054  1.202270  ...  0.562706  0.743314  0.064038  0.677842
# 8  1.309452 -0.117545  0.416642  ...  0.067404 -0.075080 -0.318150  0.074391
#
#         V24       V25       V26       V27       V28  Class
# 0 -0.281497  0.024444 -0.107944  0.625289  0.315677    1.0
# 1 -1.284021  0.651209 -0.185780  0.117897  0.013736    0.0
# 2  0.044493  0.560137 -0.058500  0.057063  0.175746    0.0
# 3  0.110095  0.040971 -0.405146  0.029348 -0.118427    0.0
# 4  0.097422 -0.316051  0.170301 -0.069562 -0.067689    0.0
# 5  0.773844 -0.067513 -0.117802  0.025809 -0.041284    0.0
# 6  0.667512  0.441140  0.681998 -0.098649 -0.050922    0.0
# 7  0.083008 -1.911034  0.322188  0.620867  0.185030    1.0
# 8 -1.072522 -0.281396 -0.022072 -0.001810 -0.015378    0.0
#
# [9 rows x 31 columns]

# %%
y = data['Class']

# %%
d_scaled.head(n=9)
# Out:
#        Time    Amount        V1        V2        V3        V4        V5  \
# 0  0.596428 -0.165015  0.949241  1.333519 -4.855402  1.835006 -1.053245
# 1 -0.780074 -0.360042  1.087114 -0.411833  1.151477  1.316336 -0.318704
# 2  1.049370 -0.436357  0.674654  0.676751 -0.712336  0.027890 -0.170944
# 3 -0.571625 -0.298142 -1.642073  1.301656  1.680965  1.602124 -0.896999
# 4  1.137317 -0.435128  2.014347 -0.043837 -0.989070  0.314874 -0.065749
# 5  1.573689 -0.249767  1.934031 -0.982692 -0.702077 -1.544121 -0.806132
# 6  0.872932 -0.423977  2.125515  0.384835 -2.555122  0.441350  1.003939
# 7 -1.652212 -0.436357  0.314597  2.660670 -5.920037  4.522500 -2.315027
# 8  1.239849  0.287956  1.595819 -0.718612 -2.292155  0.068588  1.019654
#
#          V6        V7        V8  ...       V20       V21       V22       V23  \
# 0 -2.562826 -2.286986  0.260906  ...  0.424608  0.306598 -0.854627  0.101177
# 1  2.026130 -1.064364  0.610577  ... -0.072400 -0.126848  0.159447 -0.240370
# 2 -0.738997 -0.706108 -2.896737  ...  0.386881 -1.002316  1.198820 -0.048622
# 3  0.838941 -0.359057  0.955273  ...  0.130893 -0.356980 -0.432642 -0.018939
# 4 -0.925282  0.132583 -0.235218  ... -0.170608 -0.223351 -0.509404  0.330980
# 5 -0.261569 -0.800494  0.102993  ... -0.084773  0.323888  1.123082  0.063054
# 6 -1.281697  0.782023 -0.514027  ... -0.118402  0.031303  0.312674 -0.040365
# 7 -2.278352 -4.684054  1.202270  ...  0.562706  0.743314  0.064038  0.677842
# 8  1.309452 -0.117545  0.416642  ...  0.067404 -0.075080 -0.318150  0.074391
#
#         V24       V25       V26       V27       V28  Class
# 0 -0.281497  0.024444 -0.107944  0.625289  0.315677    1.0
# 1 -1.284021  0.651209 -0.185780  0.117897  0.013736    0.0
# 2  0.044493  0.560137 -0.058500  0.057063  0.175746    0.0
# 3  0.110095  0.040971 -0.405146  0.029348 -0.118427    0.0
# 4  0.097422 -0.316051  0.170301 -0.069562 -0.067689    0.0
# 5  0.773844 -0.067513 -0.117802  0.025809 -0.041284    0.0
# 6  0.667512  0.441140  0.681998 -0.098649 -0.050922    0.0
# 7  0.083008 -1.911034  0.322188  0.620867  0.185030    1.0
# 8 -1.072522 -0.281396 -0.022072 -0.001810 -0.015378    0.0
#
# [9 rows x 31 columns]

# %%
"""# Dimensionality Reduction"""

from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=7)

# %%
X_temp_reduced = pca.fit_transform(d_scaled)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.68165306, 0.09511217, 0.0756554 , 0.03357139, 0.03293226,
#        0.01124712, 0.00822483])

# %%
names=['Time','Amount','Transaction Method','Transaction Id','Location','Type of Card','Bank']

# %%
X_reduced= pd.DataFrame(X_temp_reduced,columns=names)
X_reduced.head(n=9)
# Out:
#        Time    Amount  Transaction Method  Transaction Id  Location  \
# 0  1.626296 -3.197111           -3.426494        0.473863  0.488745
# 1 -9.884008  0.530641            1.158528       -1.471263  0.232515
# 2 -9.151924  3.386312            0.661400       -1.170874  1.893406
# 3 -8.943659  1.110908            2.651971       -1.229971 -0.372953
# 4 -9.782567  0.464092            1.172931       -0.778629  0.303076
# 5 -9.911596  0.567576            1.546208       -1.686693 -0.078754
# 6 -9.479254  0.307918            0.654966        1.193742  0.574164
# 7  7.048448 -4.479214           -4.859355        1.538096  0.939223
# 8 -9.457061  0.319898            0.856216        1.213722  0.393723
#
#    Type of Card      Bank
# 0     -1.095003  1.586177
# 1     -0.887786  0.033045
# 2     -0.991919  0.470225
# 3     -0.549827 -1.454921
# 4     -1.350770  1.043664
# 5     -1.060243  1.946681
# 6     -1.319651  1.391500
# 7     -1.760670  0.933230
# 8     -0.177186  2.068315

# %%
Y=d_scaled['Class']

# %%
new_data=pd.concat([X_reduced,Y],axis=1)
new_data.head()
new_data.shape
# Out:
# (4000, 8)

# %%
new_data.to_csv('finaldata.csv')

# %%
X_train, X_test, y_train, y_test= train_test_split(X_reduced, d_scaled['Class'], test_size = 0.30, random_state = 42)

# %%
X_train.shape, X_test.shape
# Out:
# ((2800, 7), (1200, 7))

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
"""# Support Vector Machine"""

from sklearn.svm import SVC
svc=SVC(kernel='rbf',probability=True)
svc.fit(X_train,y_train)
y_pred_svc=svc.predict(X_test)
y_pred_svc
# Out:
# array([1., 1., 1., ..., 0., 1., 1.])

# %%
print(classification_report(y_test,y_pred_svc))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.99      0.97       617
#          1.0       0.99      0.94      0.96       583
#
#     accuracy                           0.96      1200
#    macro avg       0.97      0.96      0.96      1200
# weighted avg       0.97      0.96      0.96      1200

# %%
print(confusion_matrix(y_test,y_pred_svc))
# Out:
# [[609   8]
#  [ 34 549]]

# %%
type(X_test)
X_test.to_csv('testing.csv')
from sklearn.model_selection import GridSearchCV
parameters = [ {'C': [1, 10, 100, 1000], 'kernel': ['rbf'], 'gamma': [0.1, 1, 0.01, 0.0001 ,0.001]}]
grid_search = GridSearchCV(estimator = svc,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           n_jobs = -1)
grid_search = grid_search.fit(X_train, y_train)
best_accuracy = grid_search.best_score_
best_parameters = grid_search.best_params_
print("Best Accuracy: {:.2f} %".format(best_accuracy*100))
print("Best Parameters:", best_parameters)
# Out:
# Best Accuracy: 97.32 %
# Best Parameters: {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
svc_param=SVC(kernel='rbf',gamma=0.01,C=100,probability=True)
svc_param.fit(X_train,y_train)
# Out:
# SVC(C=100, gamma=0.01, probability=True)

# %%
from sklearn.metrics import roc_curve,roc_auc_score

# %%
svc_fpr,svc_tpr,svc_threshold=roc_curve(y_test,y_pred_svc)

# %%
plt.figure(figsize=(15,10))
plt.title("Roc Curve")
plt.plot(svc_fpr, svc_tpr, label='Support Vector Classifier Score: {:.4f}'.format(roc_auc_score(y_test, y_pred_svc)))
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.legend()
plt.show()

# %%
import pickle
# Saving model to disk
pickle.dump(svc_param, open('model.pkl','wb'))

model=pickle.load(open('model.pkl','rb'))
